# %%
print("Hello World")
# Out:
# Hello World

# %%
name="najiya"
print(name)
# Out:
# najiya

# %%
a=40
print(a)
# Out:
# 40

# %%
x=30
y=20
print(x+y)
# Out:
# 50

# %%
x=20
y=3.0
z="80"
print(x)
print(y)
print(z)
# Out:
# 20
# 3.0
# 80

# %%
x=30
y=2.0
z="80"
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
x=10
y=3.89
x,y = y,x
print(x)
print(y)
# Out:
# 3.89
# 10

# %%
x="25"
a=int(x)
print(a)
print(type(a))
# Out:
# 25
# <class 'int'>

# %%
x=20
a=str(x)
print(a)
print(type(a))
# Out:
# 20
# <class 'str'>

# %%
a = int(input("Enter the 1st number :"))
b = int(input("Enter the 2nd number :"))
print(a+b)
# Out:
# Enter the 1st number : 6
# Enter the 2nd number : 9
# 15

# %%
a = int(input("Enter the 1st number:"))
b = int(input("Enter the 2nd number:"))
print(a*b)
# Out:
# Enter the 1st number: 5
# Enter the 2nd number: 6
# 30

# %%
name=input("enter your name:")
print(name)
# Out:
# enter your name: najiya
# najiya
