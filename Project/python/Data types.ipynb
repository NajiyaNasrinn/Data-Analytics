# %%
x=5
print(type(x))
# Out:
# <class 'int'>

# %%
x="hello world"
print(type(x))
# Out:
# <class 'str'>

# %%
x=3.45
print(type(x))
# Out:
# <class 'float'>

# %%
x=1j
print(type(x))
# Out:
# <class 'complex'>

# %%
x=["apple","banana"]
print(type(x))
# Out:
# <class 'list'>

# %%
x={"apple","banana"}
print(type(x))
# Out:
# <class 'set'>

# %%
x=True
print(type(x))
# Out:
# <class 'bool'>

# %%
x=range(8)
print(x)
print(type(x))
print(list(x))
# Out:
# range(0, 8)
# <class 'range'>
# [0, 1, 2, 3, 4, 5, 6, 7]

# %%
x=b"hello"
print(x)
print(type(x))
# Out:
# b'hello'
# <class 'bytes'>

# %%
x=bytearray(5)
print(x)
print(type(x))
# Out:
# bytearray(b'\x00\x00\x00\x00\x00')
# <class 'bytearray'>

# %%
x=memoryview(bytes(5))
print(type(x))
# Out:
# <class 'memoryview'>

# %%
x=frozenset({"apple","banana"})
print(type(x))
# Out:
# <class 'frozenset'>

# %%
x=None
print(type(x))
# Out:
# <class 'NoneType'>
