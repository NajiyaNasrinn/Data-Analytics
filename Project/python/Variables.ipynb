# %%
x=50
print(x)
# Out:
# 50

# %%
a="hello"
print(a)
# Out:
# hello

# %%
x=50
a="hello"
print(x)
print(a)
# Out:
# 50
# hello

# %%
x,y,z="Orange","Banana","Cherry"
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry

# %%
x=y=z="Apple"
print(x)
print(y)
print(z)
# Out:
# Apple
# Apple
# Apple

# %%
fruits=["apple","banana","cherry"]
x,y,z=fruits
print(x)
print(y)
print(z)
# Out:
# apple
# banana
# cherry

# %%
x="Python"
y="is"
z="awesome"
print(x,y,z)
# Out:
# Python is awesome

# %%
x="Python "
y="is "
z="awesome "
print(x+y+z)
# Out:
# Python is awesome

# %%
x=10
y=30
print(x+y)
# Out:
# 40

# %%
x="awesome"
def myfunc():
    print("Python is "+ x)
myfunc()
# Out:
# Python is awesome

# %%
x="awesome"
def myfunc():
    x="fantastic"
    print("Python is "+ x)
myfunc()
print("Python is "+ x)
# Out:
# Python is fantastic
# Python is awesome

# %%
x="awesome"
def myfunc():
    global x
    x="fantastic"
myfunc()
print("Python is "+ x)
# Out:
# Python is fantastic

# %% [markdown]
# TASKS

# %%
#Create a variable name and store your name in it. Print the variable.
name = "Najiya Nasrin"
print(name)
# Out:
# Najiya Nasrin

# %%
#Create variables to store your age, height, and city. Print all three values.
age = 22
height = 160
city = "cherpulassery"
print(age)
print(height)
print(city)
# Out:
# 22
# 160
# cherpulassery

# %%
#Create two variables a and b with values 25 and 15. Print their values.
a = 25
b = 15
print(a)
print(b)
# Out:
# 25
# 15

# %%
#Create three variables to store the marks of English, Maths, and Science. Print the marks
english = 85
maths = 70
science = 80
print(english)
print(maths)
print(science)
# Out:
# 85
# 70
# 80

# %%
#Create a variable price and store 500 in it. Update the value to 750 and print it
price = 500
price = 750
print(price)
# Out:
# 750

# %%
#Create a variable score with the value 80. Increase its value by 10 and print the result
score = 80
score1 = score + 10
print(score1)
# Out:
# 90

# %%
#Create two variables a = 10 and b = 20. Swap their values and print the result
a = 10
b = 20
a,b = b,a
print(a)
print(b)
# Out:
# 20
# 10

# %%
#Create variables for a product name, price, and quantity. Display all the values
product_name = "pen"
price = 20
quantity = 2
print(product_name)
print(price)
print(quantity)
# Out:
# pen
# 20
# 2

# %%
#Create variables length = 20 and width = 10. Calculate and store the area of the rectangle in another variable and print it
length = 20
width = 10
rectangle = length * width
print("Area of rectangle:",rectangle)
# Out:
# Area of rectangle: 200

# %%
#Create variables for three subject marks and store their total in a variable called total
english = 80
social = 78
maths = 85
total = english + social + maths
print(total)
# Out:
# 243

# %%
#Create variables principal, rate, and time. Calculate simple interest and store the result in a variable
principal = 1000
rate = 5
time = 2
simple_interest = (principal*rate*time)/100
print("Simple interest:",simple_interest)
# Out:
# Simple interest: 100.0

# %%
#Create a variable num and store a number in it. Create another variable to store its square
num = 5
square = num * num
print(square)
# Out:
# 25

# %%
#Create a variable num and store a number in it. Create another variable to store its cube.
num = 9
cube = num**3
print(cube)
# Out:
# 729

# %%
#Create two variables containing numbers and store their sum, difference, product, and division in separate variables.
a = 50
b = 40
sum = a + b
difference = a - b
product = a * b
quotient = a / b
print(sum)
print(difference)
print(product)
print(quotient)
# Out:
# 90
# 10
# 2000
# 1.25

# %%
#Create variables to store a student's name, roll number, course, and marks. Display all the details
name = "John"
roll_no = 20
course = "Python"
marks = 80
print(name) 
print(roll_no) 
print(course) 
print(marks)
# Out:
# John
# 20
# Python
# 80
