# %%
x="white is a colour"
print("colour" in x)
# Out:
# True

# %%
a="i am a btech gratuate"
if "btech" in a:
 print("yes,'btech' is present")
# Out:
# yes,'btech' is present

# %%
x="white is a colour"
print("red" not in x)
# Out:
# True

# %%
x="white is a colour"
if "red" not in x:
    print("no,'red' is not present")
# Out:
# no,'red' is not present

# %%
x = "najiya"
print(x[0])
# Out:
# n

# %%
x = "najiya"
print(x[-1])
# Out:
# a

# %%
x = "najiya"
print(x[::-1])
# Out:
# ayijan

# %%
x = "najiya"
print(x.upper())
# Out:
# NAJIYA

# %%
x = "NAJIYA"
print(x.lower())
# Out:
# najiya

# %%
x = "najiya"
print(x.replace("j","d"))
# Out:
# nadiya
