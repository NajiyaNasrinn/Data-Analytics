# %%
x = int(input("Enter the 1st number:"))
y = int(input("Enter the 2nd number:"))
print("Sum:",x+y)
print("Difference:",x-y)
print("Product:",x*y)
print("Quotient:",x/y)
print("Exponential:",x**y)
print("Modulus:",x%y)
print("Floor division:",x//y)
# Out:
# Enter the 1st number: 15
# Enter the 2nd number: 3
# Sum: 18
# Difference: 12
# Product: 45
# Quotient: 5.0
# Exponential: 3375
# Modulus: 0
# Floor division: 5

# %%
l = int(input("Enter the length:"))
b = int(input("Enter the breadth:"))
print("Area of Rectangle:",l*b)
print("Perimeter of Rectangle:",2*(l+b))
# Out:
# Enter the length: 10
# Enter the breadth: 5
# Area of Rectangle: 50
# Perimeter of Rectangle: 30

# %%
P = int(input("Enter the value:"))
R = int(input("Enter the rate:"))
T = int(input("Enter the time:"))
print("Simple Interest,SI:",(P*R*T)/100)
# Out:
# Enter the value: 1000
# Enter the rate: 15
# Enter the time: 2
# Simple Interest,SI: 300.0

# %%
x = int(input("Enter the value:"))
print("square:",x**2)
print("cube:",x**3)
# Out:
# Enter the value: 5
# square: 25
# cube: 125

# %%
C = int(input("Enter the celsius value:"))
print("Fahrenheit,F:",(C*(9/5))+32)
# Out:
# Enter the celsius value: 89
# Fahrenheit,F: 192.20000000000002

# %%
x = int(input("Enter the value:"))
if(x>=50 and x<=100):
 print("Yes,it is true")
else:
 print("it is false")
# Out:
# Enter the value: 80
# Yes,it is true

# %%
a = int(input("enter the 1st value:"))
b = int(input("enter the 2nd value:"))
c = int(input("enter the 3rd value:"))
print("Average:",(a+b+c)/3)
# Out:
# enter the 1st value: 30
# enter the 2nd value: 15
# enter the 3rd value: 7
# Average: 17.333333333333332

# %% [markdown]
# # Python list

# %%
x = ["red","blue","yellow","orange"]
print(len(x))
# Out:
# 4

# %%
x = ["c","java","html"]
x.append("python")
print(x)
# Out:
# ['c', 'java', 'html', 'python']

# %%
x = ["apple","banana","orange","grapes","pineapple","blueberry"]
x.insert(2,"strawberry")
print(x)
# Out:
# ['apple', 'banana', 'strawberry', 'orange', 'grapes', 'pineapple', 'blueberry']

# %%
x = ["apple","banana","orange","grapes","pineapple","mango"]
x[3]="blueberry"
print(x)
# Out:
# ['apple', 'banana', 'orange', 'blueberry', 'pineapple', 'mango']

# %%
x = ["apple","banana","orange","mango","pineapple","grapes"]
x.remove("mango")
print(x)
# Out:
# ['apple', 'banana', 'orange', 'pineapple', 'grapes']

# %%
x = ["apple","banana","orange","mango","pineapple","grapes"]
x.pop(1)
print(x)
# Out:
# ['apple', 'orange', 'mango', 'pineapple', 'grapes']

# %%
x = ["apple","banana","orange"]
y = ["mango","grapes","pineapple"]
x.extend(y)
print(x)
# Out:
# ['apple', 'banana', 'orange', 'mango', 'grapes', 'pineapple']

# %%
x = ["apple","banana","orange","mango","pineapple","grapes"]
x.clear()
print(x)
# Out:
# []
