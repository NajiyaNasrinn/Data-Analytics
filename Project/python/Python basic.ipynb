# %%
print("najiya")
print("cherpulassery")
# Out:
# najiya
# cherpulassery

# %%
a = int(input("enter a number:"))
print(a*a)
# Out:
# enter a number: 5
# 25

# %%
a = str(input("enter the name :"))
print("hello",a)
# Out:
# enter the name : python
# hello python

# %%
a = str(input("Enter the city:"))
print("I live in the",a)
# Out:
# Enter the city: cherpulassery
# I live in the cherpulassery
