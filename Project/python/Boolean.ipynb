# %%
#Check whether a student with 78 marks has passed if the pass mark is 40
pass_mark = 40
mark = 78
print(mark > pass_mark)
print("student is passed")
# Out:
# True
# student is passed

# %%
#Check whether a person aged 22 is eligible to vote.
age = 22
if age > 18 :
    print(age>18)
    print("is eligible to vote")
# Out:
# True
# is eligible to vote

# %%
#Check whether 45 is greater than 30 and less than 50.
num = 45
(num > 30 and num < 50)
# Out:
# True

# %%
#Check whether the price ₹850 is less than or equal to ₹1000
price = 850
print(price <= 1000)
# Out:
# True

# %%
#Check whether the temperature 35°C is greater than 30°C.
temp = 35
print(temp > 30)
# Out:
# True

# %%
#Check whether the number 64 is an even number
number = 64
print(number % 2 == 0)
print("is an even number")
# Out:
# True
# is an even number

# %%
#Check Check whether the string "Python" is equal to "python"
text = "Python"
strg = "python"
print(text == strg)
# Out:
# False

# %%
#Check whether a person aged 17 is eligible for a driving license if the minimum age is 18
aged = 17
min_age = 18
print(aged >= min_age)
# Out:
# False

# %%
#Check whether 95 is greater than or equal to 90
numbr = 95
print(numbr >= 90)
# Out:
# True

# %%
#Check whether the number 125 is between 100 and 200
numb = 125
print(numb > 100 and numb < 200)
# Out:
# True
