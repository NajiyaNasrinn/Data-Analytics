# %% [markdown]
# find the longest word

# %%
#example 1
sentence = "Python is a powerful programming language"
longest_word = ""
for word in sentence.split():
    if len(word)>len(longest_word):
        longest_word = word
print("Longest word is :",longest_word)
# Out:
# Longest word is : programming

# %%
#example 2
sentence_1 = "Data Analytics with Python"
longest = ""
for word in sentence_1.split():
    if len(word)>len(longest):
        longest = word
print("Longest word is :",longest)
# Out:
# Longest word is : Analytics

# %% [markdown]
# Shift all zeros to the end

# %%
#example
array=[7, 0, 5 ,0, 3 ,8 ,0 ,2]
j=0
for i in range(len(array)):
    if array!=0:
        array[j]=array[i]
        j=j+1
while j<len(array):
   array[j]=0
   j=j+1
print(array)
# Out:
# [7, 0, 5, 0, 3, 8, 0, 2]

# %%
arry=[0,1,2,3,4,5,6]
x=0
for i in range(len(arry)):
    if arry!=0:
        arry[x]=arry[i]
        x+=1

while x<len(arry):
    arry[x]=0
    x+=1
print(arry)
# Out:
# [0, 1, 2, 3, 4, 5, 6]
